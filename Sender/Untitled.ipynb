# %%
import pandas as pd
import matplot as plt

# %%
csv = pd.read_csv("sender_out.csv", sep='|')
csv_cwnd = csv[['Time', 'cwnd']]
csv_cwnd.plot(x='Time')

# %%
csv = pd.read_csv("sender_out.csv", sep='|')
csv = csv.loc[csv['Event'] == "RECIEVE"]
csv_rtt_srtt = csv[['Pack.Num', 'RTT', 'sRTT']]
csv_rtt_srtt.plot(x='Pack.Num')

# %%
csv
# Out:
#     Pack.Num    Time    Event  Eff.Win  cwnd    RTT   sRTT   TOut
# 2          0    2.05  RECIEVE        1     2   2.01   8.40  16.80
# 4          1    4.06  RECIEVE        2     3   2.00   7.12  14.24
# 9          4   19.88  RECIEVE        1     2  14.51   8.60  17.20
# 14         5   39.08  RECIEVE        0     2  19.21  10.72  34.40
# 15         6   39.09  RECIEVE        1     2  18.19  10.52  21.04
# 18         7   75.49  RECIEVE        1     2  36.41  15.70  42.07
# 20         8   75.49  RECIEVE        1     2  35.40  15.49  30.99
# 22         9   77.49  RECIEVE        1     2   2.00  12.80  25.59
# 24        10   78.50  RECIEVE        1     2   2.01  10.64  21.28
# 27        11  105.09  RECIEVE        0     2  27.60  14.03  42.55
# 28        12  105.09  RECIEVE        1     2  26.54  13.82  27.64
# 33        13  149.65  RECIEVE        0     2  44.56  19.97  55.27
# 34        14  149.66  RECIEVE        1     2  43.52  19.76  39.52
# ...

# %%
csv = pd.read_csv("sender_out.csv", sep='|')
csv = csv.loc[csv['Event'] == "RECIEVE"]
csv_rtt_srtt = csv[['Pack.Num', 'RTT', 'sRTT']]
csv_rtt_srtt.plot(x='Pack.Num')

# %%
csv
# Out:
#      Pack.Num    Time    Event  Eff.Win  cwnd    RTT  sRTT   TOut
# 1           0    2.07  RECIEVE        1     2   2.01  8.40  16.81
# 3           1    4.07  RECIEVE        2     3   2.00  7.12  14.25
# 8           2   20.48  RECIEVE        0     2  16.41  8.98  56.98
# 10          3   21.43  RECIEVE        0     2  16.28  8.95  56.98
# 11          4   23.44  RECIEVE        0     2   2.00  6.10  12.20
# 15          5   37.64  RECIEVE        0     2  14.21  7.72  24.40
# 16          6   39.65  RECIEVE        0     2   2.01  5.28  10.56
# 19          7   52.22  RECIEVE        1     2  12.57  6.74  21.12
# 21          8   54.22  RECIEVE        0     2   2.00  4.63   9.25
# 24          9   56.23  RECIEVE        0     2   2.01  4.10   8.20
# 25         10   58.23  RECIEVE        0     2   2.01  3.68   7.36
# 29         11   67.60  RECIEVE        0     2   9.37  4.82  14.73
# 30         12   69.61  RECIEVE        0     2   2.01  3.35   6.69
# ...

# %%
csv
# Out:
#     Pack.Num    Time    Event  Eff.Win  cwnd    RTT   sRTT   TOut
# 0          0    1.04     SEND        1     1   0.00   0.00  10.00
# 1          1    2.05     SEND        0     1   0.00   0.00  10.00
# 2          0    3.06  RECIEVE        0     2   2.01   8.40  16.80
# 3          2    3.06     SEND        0     2   0.00   0.00  10.00
# 4          1    4.05  RECIEVE        2     3   2.00   7.12  14.24
# 5          3    4.14     SEND        1     3   0.00   0.00  14.24
# 6          4    5.25     SEND        0     3   0.00   0.00  14.24
# 7          3   18.39   RESEND        0     1   0.00   0.00  14.24
# 8          2   19.86   RESEND        0     1   0.00   0.00  10.00
# 9          5   19.87     SEND        1     2   0.00   0.00  56.98
# 10         4   19.87  RECIEVE        1     2  14.67   8.63  17.26
# 11         6   20.92     SEND        0     2   0.00   0.00  17.26
# 12         5   37.13   RESEND        0     1   0.00   0.00  56.98
# ...

# %%
0.8*14.12 + 0.2*2
# Out:
# 11.696
